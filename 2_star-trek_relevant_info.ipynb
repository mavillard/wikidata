# %%
import json
import pickle

# %%
with open('pickle/star-trek_all_properties_dict.pickle', 'rb') as f:
    all_properties_dict = pickle.load(f)

with open('pickle/star-trek_all_types_dict.pickle', 'rb') as f:
    all_types_dict = pickle.load(f)

with open('pickle/star-trek_all_instances_dict.pickle', 'rb') as f:
    all_instances_dict = pickle.load(f)

# %%
all_properties_dict
# Out:
# {'P1005': {'description': 'identifier for the Portuguese National Library',
#   'name': 'PTBNP identifier'},
#  'P1006': {'description': 'identifier from the National Thesaurus for Author names (Dutch author-name thesaurus)',
#   'name': 'NTA identifier (Netherlands)'},
#  'P101': {'description': 'fields of work related to this item (physics, history). For occupation like physicist, historian see P106. Note: Can be used in any item, including person',
#   'name': 'field of work'},
#  'P1019': {'description': 'newsfeed (rss, atom etc.) of this person/organisation/project',
#   'name': 'feed URL'},
#  'P103': {'description': 'language that a person learned natively',
#   'name': 'native language'},
#  'P106': {'description': 'occupation of a person; see also "field of work" (Property:P101)',
#   'name': 'occupation'},
#  'P1074': {'description': 'used to link a class of items appearing in a creative work with the analogous class of objects in the real world',
# ...

# %%
# Manually selected
relevant_properties_dict = {
 'P1005': {'description': 'identifier for the Portuguese National Library',
  'name': 'PTBNP identifier'},
 'P1006': {'description': 'identifier from the National Thesaurus for Author names (Dutch author-name thesaurus)',
  'name': 'NTA identifier (Netherlands)'},
 'P101': {'description': 'fields of work related to this item (physics, history). For occupation like physicist, historian see P106. Note: Can be used in any item, including person',
  'name': 'field of work'},
 'P1019': {'description': 'newsfeed (rss, atom etc.) of this person/organisation/project',
  'name': 'feed URL'},
 'P103': {'description': 'language that a person learned natively',
  'name': 'native language'},
 'P106': {'description': 'occupation of a person; see also "field of work" (Property:P101)',
  'name': 'occupation'},
 'P1074': {'description': 'used to link a class of items appearing in a creative work with the analogous class of objects in the real world',
  'name': 'fictional analog of'},
 'P1080': {'description': "subject's fictional entity is in the object narrative. See also P1441 and P1445",
  'name': 'from fictional universe'},
 'P110': {'description': 'illustrator of a book', 'name': 'illustrator'},
 'P1104': {'description': 'number of pages in an edition of a written work',
  'name': 'number of pages'},
 'P1151': {'description': 'Wikimedia portal associated with this topic',
  'name': "topic's main Wikimedia portal"},
 'P1165': {'description': 'home world/planet of a fictional race or character',
  'name': 'home world'},
 'P1196': {'description': "circumstances of a person's death; one of: natural causes, accident, suicide, homicide, pending investigation or special 'unknown value'.  Use 'cause of death' (P509) for more immediate or underlying causes and events, e.g. heart attack, car accident",
  'name': 'manner of death'},
 'P1204': {'description': 'primary topic of this Wikimedia portal',
  'name': "Wikimedia portal's main topic"},
 'P1207': {'description': 'identifier for authority control in the Center of Warsaw University Library catalog',
  'name': 'NUKAT (WarsawU) authorities'},
 'P122': {'description': "the subject's government",
  'name': 'basic form of government'},
 'P123': {'description': 'organization responsible for publishing books, periodicals or software',
  'name': 'publisher'},
 'P1233': {'description': 'identifier for a person in the Internet Speculative Fiction Database',
  'name': 'ISFDB author ID'},
 'P1235': {'description': 'identifier for a series, periodical or franchise in the Internet Speculative Fiction Database',
  'name': 'ISFDB series ID'},
 'P1237': {'description': 'identifier for a movie at the website Box Office Mojo',
  'name': 'Box Office Mojo film ID'},
 'P1245': {'description': '"Defined Meaning" on the site OmegaWiki',
  'name': 'OmegaWiki Defined Meaning'},
 'P1258': {'description': 'identifier on Rotten Tomatoes: must use prefix "m/" for movies, "tv/" for TV series (remove /s number on end unless the item is a specific season), "celebrity/" for celebrities, "critic/" for film critics, "source-" for review sources',
  'name': 'Rotten Tomatoes identifier'},
 'P1265': {'description': 'identifier for a movie in the AlloCiné film database',
  'name': 'AlloCiné movie ID'},
 'P1273': {'description': 'identifier for authority control managed by the National Library of Catalonia (BNC)',
  'name': 'CANTIC'},
 'P1284': {'description': 'identifier on the Munzinger Archiv',
  'name': 'Munzinger IBA'},
 'P131': {'description': 'the item is located on the territory of the following administrative entity',
  'name': 'located in the administrative territorial entity'},
 'P135': {'description': 'literary, artistic or philosophical movement associated with this person or work',
  'name': 'movement'},
 'P136': {'description': 'genre of a creative work or genre in which an artist works',
  'name': 'genre'},
 'P137': {'description': 'person or organization that operates the equipment, facility, or service',
  'name': 'operator'},
 'P138': {'description': "entity or event that inspired the subject's name, or namesake (in at least one language)",
  'name': 'named after'},
 'P140': {'description': 'religion of a person or organization (MUST be claimed by the subject or documented by historical sources)',
  'name': 'religion'},
 'P1407': {'description': 'identifier for a series per the MusicBrainz open music encyclopedia',
  'name': 'MusicBrainz series ID'},
 'P1412': {'description': 'language(s) that a person speaks or writes. Can include native languages',
  'name': 'languages spoken or written'},
 'P1430': {'description': 'identifier for a person or other subject in the OpenPlaques database - http://openplaques.org/',
  'name': 'OpenPlaques subject identifier'},
 'P1434': {'description': 'the subject is a work describing a fictional universe, ie where the plot occurs in this universe.',
  'name': 'describes the fictional universe'},
 'P144': {'description': 'the work(s) used as basis for subject',
  'name': 'based on'},
 'P1441': {'description': 'work in which this fictional entity (Q14897293) is present. See also P:1080 for in-universe information',
  'name': 'present in work'},
 'P1445': {'description': 'to link a fictional universe with a work that describes it: <universe> "described in the work:" <work>',
  'name': 'fictional universe described in'},
 'P1476': {'description': 'the title of a work', 'name': 'title'},
 'P150': {'description': '(list of) direct subdivisions of an administrative entity',
  'name': 'contains administrative territorial entity'},
 'P154': {'description': 'graphic mark or emblem commonly used by commercial enterprises, organizations and products',
  'name': 'logo image'},
 'P155': {'description': 'The immediately prior item in some series of which the subject is part. Use P1365 (replaces) if the preceding item was replaced, e.g. political offices, states and there is no identity between precedent and following geographic unit',
  'name': 'follows'},
 'P156': {'description': 'The immediately following item in some series of which the subject is part. Use P1366 (replaced by) if the item is replaced, e.g. political offices, states',
  'name': 'followed by'},
 'P1562': {'description': 'identifier for a movie on the site AllMovie',
  'name': 'AllMovie movie ID'},
 'P161': {'description': 'production\'s cast members; to add the roles, use "character role" (P453) as qualifier',
  'name': 'cast member'},
 'P162': {'description': 'producer(s) of this film or music work (film: not executive producers, associate producers, etc.)',
  'name': 'producer'},
 'P1651': {'description': 'identifier of a notable video on YouTube',
  'name': 'YouTube video identifier'},
 'P166': {'description': 'award or recognition received by a person, organisation or creative work',
  'name': 'award received'},
 'P17': {'description': 'sovereign state of this item', 'name': 'country'},
 'P170': {'description': 'maker of a creative work or other object (where no more specific property exists)',
  'name': 'creator'},
 'P1712': {'description': 'identifier in Metacritic', 'name': 'Metacritic ID'},
 'P172': {'description': "subject's ethnicity (consensus is that a VERY high standard of proof is needed for this field to be used. In general this means 1) the subject claims it him/herself, or 2) it is widely agreed on by scholars, or 3) is fictional and portrayed as such).",
  'name': 'ethnic group'},
 'P1728': {'description': 'identifier for an artist in AllMusic database',
  'name': 'AllMusic artist ID'},
 'P175': {'description': 'musician, music group, or other performer associated with this work',
  'name': 'performer'},
 'P176': {'description': 'main manufacturer of this product (excluding sub-contracted manufacturers)',
  'name': 'manufacturer'},
 'P1766': {'description': 'image of road sign with place name on it',
  'name': 'place name sign'},
 'P178': {'description': 'organisation or person that developed this item',
  'name': 'developer'},
 'P179': {'description': 'the subject is part of a series, whose sum constitutes the object',
  'name': 'series'},
 'P18': {'description': 'image of relevant illustration of the subject; if available, use more specific properties (sample: coat of arms image, locator map, flag image, signature image, logo image); only images which exist on Wikimedia Commons are acceptable',
  'name': 'image'},
 'P180': {'description': 'depicted entity (see also P921: subject heading)',
  'name': 'depicts'},
 'P1804': {'description': 'identifier for a film in the Danish National Filmography',
  'name': 'Danish National Filmography ID'},
 'P1811': {'description': 'link to the article with the list of episodes for this series',
  'name': 'list of episodes'},
 'P1813': {'description': 'short name of a place, organisation, person etc.',
  'name': 'short name'},
 'P19': {'description': 'the most specific known (e.g. city instead of country, or hospital instead of city)',
  'name': 'place of birth'},
 'P194': {'description': 'legislative body governing this entity; political institution with elected representatives, such as a parliament/legislature or council',
  'name': 'legislative body'},
 'P1953': {'description': 'identifier for a band or person in the Discogs database',
  'name': 'Discogs artist ID'},
 'P196': {'description': 'is in grouping of minor planets according to similar orbital characteristics',
  'name': 'minor planet group'},
 'P1970': {'description': 'idMovieMeter movie identifierentifier for a movie on the website MovieMeter',
  'name': 'MovieMeter movie ID'},
 'P20': {'description': 'the most specific known (e.g. city instead of country, or hospital instead of city)',
  'name': 'place of death'},
 'P2002': {'description': "this item's username on Twitter",
  'name': 'Twitter username'},
 'P2003': {'description': "this item's username on Instagram",
  'name': 'Instagram username'},
 'P2013': {'description': 'identifier for a person or organization in Facebook',
  'name': 'Facebook ID'},
 'P21': {'description': 'Sexual identity of  subject. Main: male (Q6581097), female (Q6581072), transgender female (Q1052281),  transgender male (Q2449503). For animals, use male animal (Q44148), female animal (Q43445). For groups of  same gender, use "subclass of" (P279)',
  'name': 'sex or gender'},
 'P212': {'description': 'identifier for a book (edition), thirteen digit',
  'name': 'ISBN-13'},
 'P213': {'description': 'identifier for an identity. (Only when displayed preceded by the letters ISNI and a space; the digits are displayed as 4 blocks of 4 digits)',
  'name': 'ISNI'},
 'P214': {'description': 'identifier in the Virtual International Authority File',
  'name': 'VIAF identifier'},
 'P219': {'description': 'identifier for a language or macrolanguage or language family language, defined in ISO 639-2 standard,\xa03-letter technical or bibliographical \xa0code',
  'name': 'ISO 639-2 code'},
 'P22': {'description': 'male parent', 'name': 'father'},
 'P220': {'description': 'identifier for a language defined in ISO 639-3',
  'name': 'ISO 639-3 code'},
 'P227': {'description': "identifier from an international authority file of names, subjects, and organizations (please don't use type n = name, disambiguation)",
  'name': 'GND identifier'},
 'P241': {'description': 'the branch to which this military unit, award, or person belongs, e.g. Royal Navy',
  'name': 'military branch'},
 'P243': {'description': 'identifier from the Online Computer Library Center',
  'name': 'OCLC control number'},
 'P244': {'description': 'Library of Congress ID for authority control (for books use P1144)',
  'name': 'LCAuth identifier'},
 'P245': {'description': 'identifier from the Getty Union List of Artist Names',
  'name': 'ULAN identifier'},
 'P25': {'description': 'female parent', 'name': 'mother'},
 'P26': {'description': 'the subject has the object as their spouse (husband, wife, partner, etc.). Use "cohabitant" for non-married companions',
  'name': 'spouse'},
 'P264': {'description': 'brand and trademark associated with the marketing of subject music recordings and music videos',
  'name': 'record label'},
 'P268': {'description': 'identifier for the subject issued by BNF (Bibliothèque nationale de France)',
  'name': 'BnF identifier'},
 'P269': {'description': 'identifier for authority control in the French collaborative library catalog (see also P1025)',
  'name': 'SUDOC authorities'},
 'P27': {'description': 'the object is a country that recognizes the subject as its citizen',
  'name': 'country of citizenship'},
 'P272': {'description': 'company that produced this film, audio or performing arts work',
  'name': 'production company'},
 'P275': {'description': 'license under which this copyrighted work is released',
  'name': 'license'},
 'P279': {'description': 'all instances of these items are instances of those items; this item is a class of that item. Not to be confused with Property:P31 (instance of).',
  'name': 'subclass of'},
 'P287': {'description': 'designer of this item', 'name': 'designer'},
 'P289': {'description': 'vessel classification (e.g. Nelson-class battleship)',
  'name': 'vessel class'},
 'P301': {'description': 'primary topic of the subject category',
  'name': "category's main topic"},
 'P305': {'description': 'identifier for a language per the Internet Engineering Task Force',
  'name': 'IETF language tag'},
 'P31': {'description': 'this item is a specific example and a member of that class. Not to be confused with Property:P279 (subclass of).',
  'name': 'instance of'},
 'P344': {'description': 'person responsible for the framing, lighting and filtration of the subject work',
  'name': 'director of photography'},
 'P345': {'description': 'identifier from the Internet Movie Database (IMDb) with prefix (tt-, nm-, ch-, co-, ev-)',
  'name': 'IMDb identifier'},
 'P348': {'description': 'version(s) of the software, current and past',
  'name': 'software version'},
 'P349': {'description': 'identifier for authority control per the National Diet Library of Japan',
  'name': 'NDL identifier'},
 'P357': {'description': 'title of a work (such as a book, a film or a website)',
  'name': '(OBSOLETE) title (use P1476, "title")'},
 'P36': {'description': 'location (city, municipality) of governmental seat of the country, or administrative territorial entity',
  'name': 'capital'},
 'P360': {'description': 'this is a list of the following items',
  'name': 'is a list of'},
 'P361': {'description': 'subject is a part of that object',
  'name': 'part of'},
 'P364': {'description': 'language in which a work was originally created',
  'name': 'original language of work'},
 'P37': {'description': 'language designated as official by this item',
  'name': 'official language'},
 'P373': {'description': 'name of the Wikimedia Commons category containing files related to this item (without the prefix "Category")',
  'name': 'Commons category'},
 'P38': {'description': 'currency used by item', 'name': 'currency'},
 'P39': {'description': 'subject currently or formerly holds the object position or public office',
  'name': 'position held'},
 'P40': {'description': 'subject has the object as their biological offspring',
  'name': 'child'},
 'P400': {'description': 'platform for which a work has been developed or released / specific platform version of a software developed',
  'name': 'platform'},
 'P404': {'description': 'available playing mode(s) in a video game',
  'name': 'game mode'},
 'P407': {'description': 'for works (for original language use P364 and for persons P103 and P1412)',
  'name': 'language of work (or name)'},
 'P408': {'description': 'software engine employed by the subject item',
  'name': 'software engine'},
 'P409': {'description': 'identifier issued by the National Library of Australia (see also P1315 for the newer People Australia identifier)',
  'name': 'NLA (Australia) identifier'},
 'P410': {'description': 'military rank achieved by a person (should usually have a "start date" qualifier)',
  'name': 'military rank'},
 'P433': {'description': 'issue of a newspaper, a scientific journal or magazine for reference purpose',
  'name': 'issue'},
 'P434': {'description': 'identifier for an artist per the MusicBrainz open music encyclopedia',
  'name': 'MusicBrainz artist ID'},
 'P435': {'description': 'identifier for a work per the MusicBrainz open music encyclopedia',
  'name': 'MusicBrainz work ID'},
 'P436': {'description': 'identifier for a release group per the MusicBrainz open music encyclopedia (album)',
  'name': 'MusicBrainz release group ID'},
 'P437': {'description': 'method (or type) of distribution for the subject',
  'name': 'distribution'},
 'P449': {'description': 'network(s) the radio or television show was originally aired on. This does not include later re-runs or additional syndication.',
  'name': 'original network'},
 'P453': {'description': 'specific role played or filled by subject -- use only as qualifier of "cast member" (P161) or "voice actor" (P725)',
  'name': 'character role'},
 'P463': {'description': 'part of a specific organization or club. Do not use for membership in ethnic or social groups, nor for holding a position such as a member of parliament (use P39 for that).',
  'name': 'member of'},
 'P47': {'description': 'countries or administrative subdivisions, of equal level, that this item borders, either by land or water',
  'name': 'shares border with'},
 'P479': {'description': 'input method or device used to interact with a software product',
  'name': 'input device'},
 'P480': {'description': 'FilmAffinity identification number of a creative work',
  'name': 'FilmAffinity identifier'},
 'P490': {'description': 'designation of an astronomical body after its discovery and before its official name',
  'name': 'provisional designation'},
 'P495': {'description': 'country of origin of the creative work or subject item',
  'name': 'country of origin'},
 'P50': {'description': 'main creator(s) of a written work', 'name': 'author'},
 'P508': {'description': 'identifier in the subject indexing tool of the National Central Library of Florence',
  'name': 'PIJAS'},
 'P509': {'description': "underlying or immediate cause of death.  Underlying cause (e.g. car accident, stomach cancer) preferred.  Use 'manner of death' (P1196) for broadest category, e.g. natural causes, accident, homicide, suicide",
  'name': 'cause of death'},
 'P527': {'description': 'object that is part of this subject',
  'name': 'has part'},
 'P535': {'description': "identifier of an individual's  burial place in the Find a Grave database",
  'name': 'Find a Grave grave ID'},
 'P553': {'description': 'a website that the person or organization has an account on (use with P554) Note: only used with reliable source or if the person or organization disclosed it.',
  'name': 'website account on'},
 'P554': {'description': 'username on a website that the person or organization has an account on (only use as qualifier of P553)',
  'name': 'website username'},
 'P569': {'description': 'date on which the subject was born',
  'name': 'date of birth'},
 'P57': {'description': 'director(s) of this motion picture, play, video game or similar',
  'name': 'director'},
 'P570': {'description': 'date on which the subject died',
  'name': 'date of death'},
 'P575': {'description': 'date or point in time when the item was discovered',
  'name': 'time of discovery'},
 'P577': {'description': 'date or point in time a work is first published or released',
  'name': 'publication date'},
 'P58': {'description': 'author(s) of the screenplay or script for this work',
  'name': 'screenwriter'},
 'P580': {'description': 'indicates the time an item begins to exist or a statement starts being valid, usually used as a qualifier',
  'name': 'start time'},
 'P582': {'description': 'indicates the time an item ceases to exist or a statement stops being valid, used as a qualifier',
  'name': 'end time'},
 'P585': {'description': 'time and date something took place, existed or a statement was true',
  'name': 'point in time'},
 'P607': {'description': 'battles, wars or engagements in which the person or item participated',
  'name': 'conflict'},
 'P61': {'description': 'discovered, first described, or invented by',
  'name': 'discoverer or inventor'},
 'P619': {'description': 'date and time of spacecraft launch in UTC',
  'name': 'time of spacecraft launch'},
 'P625': {'description': 'geocoordinates of the subject',
  'name': 'coordinate location'},
 'P641': {'description': 'sport or discipline in which the entity participates or belongs to',
  'name': 'sport'},
 'P642': {'description': 'qualifiers stating that a statement applies within the scope of a particular item',
  'name': 'of'},
 'P646': {'description': 'identifer for a page in the Freebase open knowledge graph',
  'name': 'Freebase identifier'},
 'P65': {'description': 'the place where an astronomical object was discovered (observatory, satellite)',
  'name': 'site of astronomical discovery'},
 'P674': {'description': 'characters which appear in this item (plays, operas, operettas, books...)',
  'name': 'characters'},
 'P69': {'description': 'educational institution attended by the subject',
  'name': 'educated at'},
 'P691': {'description': 'identifier in the National authority file of the Czech Republic (National Library of CR)',
  'name': 'NKC identifier'},
 'P7': {'description': 'subject has the object as their brother',
  'name': 'brother'},
 'P706': {'description': 'located on the specified landform or body of water. Should not be used when the value is only political/administrative (provinces, states, countries, etc.).',
  'name': 'located on terrain feature'},
 'P716': {'description': 'identifier in the\xa0JPL Small-Body Database',
  'name': 'JPL Small-Body Database identifier'},
 'P734': {'description': 'surname or last name of a person',
  'name': 'family name'},
 'P735': {'description': "first name or another given name of this person. Values used with the property shouldn't link disambiguations nor family names.",
  'name': 'given name'},
 'P750': {'description': 'distributor of a creative work',
  'name': 'distributor'},
 'P793': {'description': 'significant or notable events associated with the subject',
  'name': 'significant event'},
 'P794': {'description': 'generic qualifier', 'name': 'as'},
 'P800': {'description': "subject's notable scientific work or work of art",
  'name': 'notable work'},
 'P840': {'description': 'the narrative of the work is set in this location',
  'name': 'narrative location'},
 'P852': {'description': "North American video game content rating - appropriate values are on property's talk page",
  'name': 'ESRB rating'},
 'P854': {'description': 'should be used for internet URLs as references',
  'name': 'reference URL'},
 'P856': {'description': 'URL to the website of this item',
  'name': 'official website'},
 'P86': {'description': 'person(s) who wrote the music; also use P676 for lyricist',
  'name': 'composer'},
 'P905': {'description': 'PORT-network film database: identifier for a film or television program',
  'name': 'PORT film ID'},
 'P908': {'description': 'European video game rating system - see talk page for appropriate values',
  'name': 'PEGI rating'},
 'P910': {'description': 'main category of this topic',
  'name': "topic's main category"},
 'P914': {'description': 'German video game content rating - see talk page for appropriate values',
  'name': 'USK rating'},
 'P915': {'description': 'actual place where this scene/film was shot',
  'name': 'filming location'},
 'P921': {'description': 'primary topic of a work', 'name': 'main subject'},
 'P94': {'description': "image of the item's coat of arms",
  'name': 'coat of arms image'},
 'P941': {'description': 'work which inspired this creative work',
  'name': 'inspired by'},
 'P950': {'description': 'identifier from the authority file of the Biblioteca Nacional de España',
  'name': 'BNE identifier'},
 'P957': {'description': 'identifier for a book (edition), ten digit',
  'name': 'ISBN-10'}
}

# %%
all_types_dict
# Out:
# {'Q101352': {'description': 'part of a naming scheme for individuals, used in many cultures worldwide',
#   'name': 'family name',
#   'superclasses': {'Q147276'},
#   'wikilink': 'Family name'},
#  'Q103495': {'description': "war affecting most of the world's most powerful and populous countries",
#   'name': 'world war',
#   'superclasses': {'Q198'},
#   'wikilink': 'World war'},
#  'Q103817': {'description': 'groups protected in legislation as having rights based on historical ties to a territory',
#   'name': 'indigenous peoples',
#   'superclasses': {'Q851990'},
#   'wikilink': 'Indigenous peoples'},
#  'Q1055307': {'description': '',
#   'name': 'fictional technology',
#   'superclasses': {'Q14897293'},
#   'wikilink': 'Fictional technology'},
#  'Q1066984': {'description': 'global city that is home to a large number of internationally significant banks, businesses, and stock exchanges',
#   'name': 'financial centre',
#   'superclasses': {'Q208511'},
# ...

# %%
# Manually selected
relevant_types_dict = {
 'Q101352': {'description': 'part of a naming scheme for individuals, used in many cultures worldwide',
  'name': 'family name',
  'superclasses': {'Q147276'},
  'wikilink': 'Family name'},
 'Q103495': {'description': "war affecting most of the world's most powerful and populous countries",
  'name': 'world war',
  'superclasses': {'Q198'},
  'wikilink': 'World war'},
 'Q103817': {'description': 'groups protected in legislation as having rights based on historical ties to a territory',
  'name': 'indigenous peoples',
  'superclasses': {'Q851990'},
  'wikilink': 'Indigenous peoples'},
 'Q1055307': {'description': '',
  'name': 'fictional technology',
  'superclasses': {'Q14897293'},
  'wikilink': 'Fictional technology'},
 'Q1066984': {'description': 'global city that is home to a large number of internationally significant banks, businesses, and stock exchanges',
  'name': 'financial centre',
  'superclasses': {'Q208511'},
  'wikilink': 'Financial centre'},
 'Q1093829': {'description': 'administrative division at the local government level in the United States',
  'name': 'city of the United States',
  'superclasses': {'Q15253706', 'Q3327870'},
  'wikilink': ''},
 'Q1114502': {'description': 'thin periodical containing primarily comics content',
  'name': 'American comic book',
  'superclasses': {'Q1760610'},
  'wikilink': 'American comic book'},
 'Q112099': {'description': 'country whose primary territory consists of one or more islands or parts of islands',
  'name': 'island nation',
  'superclasses': {'Q6256', 'Q7275'},
  'wikilink': 'Island country'},
 'Q11266439': {'description': "type of page in the Wikimedia system. Use with P31 'instance of' for template pages",
  'name': 'Wikimedia template',
  'superclasses': {'Q14204246', 'Q17442446'},
  'wikilink': 'Wikipedia:Template namespace'},
 'Q11367794': {'description': '',
  'name': '',
  'superclasses': set(),
  'wikilink': ''},
 'Q1137046': {'description': '',
  'name': 'list of Star Trek: The Next Generation episodes',
  'superclasses': set(),
  'wikilink': 'List of Star Trek: The Next Generation episodes'},
 'Q1137109': {'description': 'publisher of video games',
  'name': 'video game publisher',
  'superclasses': {'Q7554349'},
  'wikilink': 'Video game publisher'},
 'Q11424': {'description': 'sequence of images that give the impression of movement',
  'name': 'film',
  'superclasses': {'Q17537576', 'Q2431196', 'Q838948'},
  'wikilink': 'Film'},
 'Q11879590': {'description': 'first name given to women',
  'name': 'female given name',
  'superclasses': {'Q202444'},
  'wikilink': ''},
 'Q1188663': {'description': 'nine institutions of higher education chartered in the American Colonies before the USA became a sovereign nation',
  'name': 'Colonial Colleges',
  'superclasses': {'Q1849445'},
  'wikilink': 'List of Colonial Colleges'},
 'Q1188693': {'description': '',
  'name': 'mind sport',
  'superclasses': {'Q31629'},
  'wikilink': 'Mind sport'},
 'Q1194240': {'description': '',
  'name': 'science fiction genre',
  'superclasses': {'Q20076756', 'Q24925'},
  'wikilink': ''},
 'Q12135': {'description': 'Human disease',
  'name': 'mental disorder',
  'superclasses': {'Q12136'},
  'wikilink': 'Mental disorder'},
 'Q12136': {'description': 'abnormal condition that affects the body of an organism',
  'name': 'disease',
  'superclasses': {'Q2057971'},
  'wikilink': 'Disease'},
 'Q1226311': {'description': 'holographic program in Star Trek',
  'name': 'Emergency Medical Hologram',
  'superclasses': {'Q95074'},
  'wikilink': ''},
 'Q12308941': {'description': 'class of first names, which are given to men',
  'name': 'male given name',
  'superclasses': {'Q202444'},
  'wikilink': ''},
 'Q1254874': {'description': 'telecommunications network for distribution of television program content',
  'name': 'television network',
  'superclasses': {'Q141683', 'Q1616075'},
  'wikilink': 'Television network'},
 'Q1257934': {'description': 'episode of a television series that consists primarily of excerpts from previous episodes',
  'name': 'clip show',
  'superclasses': {'Q1983062'},
  'wikilink': 'Clip show'},
 'Q1307214': {'description': '',
  'name': 'form of government',
  'superclasses': {'Q183039'},
  'wikilink': ''},
 'Q131436': {'description': 'game that involves counters or pieces moved or placed on a pre-marked surface or "board", according to a set of rules',
  'name': 'board game',
  'superclasses': {'Q3244175'},
  'wikilink': 'Board game'},
 'Q13218382': {'description': 'type of division of California',
  'name': 'charter city and county',
  'superclasses': {'Q13212489', 'Q13218391', 'Q3301053'},
  'wikilink': ''},
 'Q13218391': {'description': 'type of city in California',
  'name': 'charter city',
  'superclasses': {'Q13218357', 'Q604886'},
  'wikilink': ''},
 'Q13218404': {'description': 'type of division of Canada',
  'name': 'province of Canada',
  'superclasses': {'Q107390', 'Q2879', 'Q34876'},
  'wikilink': ''},
 'Q1323642': {'description': '',
  'name': 'transcontinental country',
  'superclasses': {'Q6256'},
  'wikilink': 'List of transcontinental countries'},
 'Q1336920': {'description': 'type of educational institution',
  'name': 'community college',
  'superclasses': {'Q2385804', 'Q811979'},
  'wikilink': 'Community college'},
 'Q13406463': {'description': 'Wikipedia (or Wikivoyage, Wikibooks, etc) article with list of something',
  'name': 'Wikimedia list article',
  'superclasses': {'Q12148816', 'Q15138389'},
  'wikilink': 'Wikipedia:Lists'},
 'Q134556': {'description': 'type of music release usually containing one or two tracks',
  'name': 'single',
  'superclasses': {'Q2031291', 'Q207628', 'Q7366'},
  'wikilink': 'Single (music)'},
 'Q13516667': {'description': 'any activity of a person (hobby, work, pastime, professional sport...)',
  'name': 'occupation',
  'superclasses': {'Q3769299'},
  'wikilink': ''},
 'Q141683': {'description': '',
  'name': 'broadcast network',
  'superclasses': {'Q15265344'},
  'wikilink': 'Broadcast network'},
 'Q14204246': {'description': "page in the 'project' (Wikipedia, Wikivoyage, Wikimedia Commons) namespace on a Wikimedia project — e.g. wikiproject",
  'name': 'Wikimedia project page',
  'superclasses': {'Q17379835'},
  'wikilink': ''},
 'Q14623646': {'description': 'organisation that exists only in fiction',
  'name': 'fictional organization',
  'superclasses': {'Q14897293'},
  'wikilink': ''},
 'Q14637321': {'description': '',
  'name': 'fictional spacecraft',
  'superclasses': {'Q18670171'},
  'wikilink': ''},
 'Q1480166': {'description': 'company with limited liability established under Japanese law',
  'name': 'kabushiki gaisha',
  'superclasses': {'Q134161'},
  'wikilink': 'Kabushiki gaisha'},
 'Q15053464': {'description': 'material that only exists in fiction and not in reality',
  'name': 'fictional material',
  'superclasses': {'Q14897293'},
  'wikilink': ''},
 'Q15063611': {'description': 'type of administrative territorial entity of New York State',
  'name': 'city of New York',
  'superclasses': {'Q1093829', 'Q47682'},
  'wikilink': ''},
 'Q1520223': {'description': '',
  'name': 'constitutional republic',
  'superclasses': {'Q7270'},
  'wikilink': ''},
 'Q15238535': {'description': 'fictional entity',
  'name': 'fictional government or government body',
  'superclasses': {'Q14623646'},
  'wikilink': ''},
 'Q15416': {'description': 'segment of content intended for broadcast on television',
  'name': 'television program',
  'superclasses': {'Q19968906'},
  'wikilink': 'Television program'},
 'Q1549591': {'description': 'city with a population of more than 100,000 inhabitants',
  'name': 'big city',
  'superclasses': {'Q515'},
  'wikilink': ''},
 'Q15632617': {'description': 'human being that only exists in fictional works',
  'name': 'fictional human',
  'superclasses': {'Q6619679', 'Q95074'},
  'wikilink': ''},
 'Q15633582': {'description': 'site whose software engine is MediaWiki',
  'name': 'MediaWiki site',
  'superclasses': {'Q171'},
  'wikilink': ''},
 'Q15690029': {'description': '',
  'name': 'fictional educational institution',
  'superclasses': {'Q14623646'},
  'wikilink': ''},
 'Q15707583': {'description': 'group of one or more fictional organism(s), which a taxonomist adjudges to be a unit',
  'name': 'fictional taxon',
  'superclasses': {'Q15831596'},
  'wikilink': ''},
 'Q15773317': {'description': '',
  'name': 'television character',
  'superclasses': {'Q95074'},
  'wikilink': ''},
 'Q15773347': {'description': '',
  'name': 'film character',
  'superclasses': {'Q95074'},
  'wikilink': ''},
 'Q15831596': {'description': '',
  'name': 'fictional class',
  'superclasses': {'Q14897293'},
  'wikilink': ''},
 'Q15936437': {'description': 'type of university',
  'name': 'research university',
  'superclasses': {'Q3918'},
  'wikilink': ''},
 'Q15961987': {'description': 'genre',
  'name': 'television genre',
  'superclasses': {'Q15416', 'Q483394'},
  'wikilink': ''},
 'Q160016': {'description': '',
  'name': 'member state of the United Nations',
  'superclasses': {'Q1646605'},
  'wikilink': 'Member states of the United Nations'},
 'Q1616075': {'description': 'business, organisation or other enterprise that transmits content over terrestrial television',
  'name': 'television station',
  'superclasses': {'Q15943455', 'Q783794'},
  'wikilink': 'Television station'},
 'Q1620797': {'description': 'group of buildings, properties, or sites that have been designated as historically or architecturally significant',
  'name': 'historic district in the United States',
  'superclasses': {'Q15243209', 'Q852446'},
  'wikilink': 'Historic districts in the United States'},
 'Q163740': {'description': 'organization that uses its income to achieve its goals rather than distributing it as profit or dividends',
  'name': 'nonprofit organization',
  'superclasses': {'Q43229'},
  'wikilink': 'Nonprofit organization'},
 'Q1637706': {'description': 'city with a population of more than 1,000,000',
  'name': 'city with millions of inhabitants',
  'superclasses': {'Q1549591'},
  'wikilink': ''},
 'Q1659605': {'description': 'fictional asteroid',
  'name': 'asteroids in fiction',
  'superclasses': {'Q15831598'},
  'wikilink': 'Asteroids in fiction'},
 'Q1700422': {'description': 'species of humanoid alien from Star Trek',
  'name': 'extraterrestrial from Star Trek',
  'superclasses': {'Q6623809'},
  'wikilink': 'List of Star Trek races'},
 'Q170434': {'description': 'group of closely-related PC-compatible operating systems',
  'name': 'DOS',
  'superclasses': {'Q9135'},
  'wikilink': 'DOS'},
 'Q171263': {'description': '',
  'name': 'agglutinative language',
  'superclasses': {'Q1427969'},
  'wikilink': 'Agglutinative language'},
 'Q17351672': {'description': '',
  'name': '',
  'superclasses': {'Q11410'},
  'wikilink': ''},
 'Q17444909': {'description': 'defines elements of the hierarchy of astronomical objects',
  'name': 'astronomical object type',
  'superclasses': {'Q217594'},
  'wikilink': ''},
 'Q1762059': {'description': 'company that produces films',
  'name': 'film production company',
  'superclasses': {'Q11396960'},
  'wikilink': ''},
 'Q17633526': {'description': 'Used on the property P31',
  'name': 'Wikinews article',
  'superclasses': {'Q15138389', 'Q5707594'},
  'wikilink': ''},
 'Q177600': {'description': 'simple drawing of a person or animal',
  'name': 'stick figure',
  'superclasses': {'Q1027879'},
  'wikilink': 'Stick figure'},
 'Q1788716': {'description': 'award, usually a medal of some sort, mark of honor',
  'name': 'military decoration',
  'superclasses': {'Q16140648', 'Q193622'},
  'wikilink': 'Military awards and decorations'},
 'Q178885': {'description': 'supernatural being',
  'name': 'deity',
  'superclasses': {'Q13127686', 'Q15619164'},
  'wikilink': 'Deity'},
 'Q179164': {'description': 'state governed as a single unit with a supreme central government',
  'name': 'unitary state',
  'superclasses': {'Q1307214', 'Q7275'},
  'wikilink': 'Unitary state'},
 'Q18002896': {'description': '',
  'name': 'television production company',
  'superclasses': {'Q1762059'},
  'wikilink': ''},
 'Q18039177': {'description': 'spacecraft class that only exists in fictional works',
  'name': 'fictional spacecraft class',
  'superclasses': {'Q14637321', 'Q15831596'},
  'wikilink': ''},
 'Q18127': {'description': 'brand and trademark associated with the marketing of music recordings and music videos',
  'name': 'record label',
  'superclasses': {'Q167270', 'Q1917775'},
  'wikilink': 'Record label'},
 'Q18328097': {'description': '',
  'name': 'courage award',
  'superclasses': {'Q618779'},
  'wikilink': ''},
 'Q184824': {'description': '',
  'name': 'pointing device',
  'superclasses': {'Q864114'},
  'wikilink': 'Pointing device'},
 'Q18533645': {'description': 'fictional spacecraft from the Star Trek universe',
  'name': 'spacecraft in Star Trek',
  'superclasses': {'Q14637321'},
  'wikilink': 'Spacecraft in Star Trek'},
 'Q185441': {'description': 'state that is party to treaties of the European Union (EU)',
  'name': 'member state of the European Union',
  'superclasses': {'Q1646605'},
  'wikilink': 'Member state of the European Union'},
 'Q18572946': {'description': '',
  'name': 'fictional space station',
  'superclasses': {'Q14637321'},
  'wikilink': ''},
 'Q186117': {'description': 'way of displaying a list of events in chronological order',
  'name': 'timeline',
  'superclasses': {'Q185363'},
  'wikilink': 'Timeline'},
 'Q188784': {'description': 'type of stock character possessing "extraordinary or superhuman powers" and dedicated to protecting the public',
  'name': 'superhero',
  'superclasses': {'Q636497'},
  'wikilink': 'Superhero'},
 'Q1907114': {'description': 'region consisting of a densely populated urban core and its less-populated surrounding territories',
  'name': 'metropolitan area',
  'superclasses': {'Q486972', 'Q56061'},
  'wikilink': 'Metropolitan area'},
 'Q1914636': {'description': 'process of doing something',
  'name': 'activity',
  'superclasses': {'Q3249551'},
  'wikilink': ''},
 'Q193395': {'description': '',
  'name': 'data storage device',
  'superclasses': {'Q286583', 'Q340169', 'Q9158768'},
  'wikilink': 'Data storage device'},
 'Q193564': {'description': 'system designed for the creation and development of video games',
  'name': 'game engine',
  'superclasses': {'Q146768', 'Q2622299'},
  'wikilink': 'Game engine'},
 'Q19595246': {'description': 'form of fictional government',
  'name': 'fictional empire',
  'superclasses': {'Q15238535'},
  'wikilink': ''},
 'Q196600': {'description': 'use of a creative work across several different media',
  'name': 'media franchise',
  'superclasses': {'Q171947', 'Q386724'},
  'wikilink': 'Media franchise'},
 'Q19689753': {'description': '',
  'name': 'Belarusian personal name',
  'superclasses': {'Q202444', 'Q4881956'},
  'wikilink': ''},
 'Q1971694': {'description': '',
  'name': 'game mode',
  'superclasses': {'Q6888088'},
  'wikilink': ''},
 'Q198': {'description': 'organised and prolonged conflict between states',
  'name': 'war',
  'superclasses': {'Q180684'},
  'wikilink': 'War'},
 'Q19803443': {'description': '',
  'name': 'initials instead of given names',
  'superclasses': {'Q202444'},
  'wikilink': ''},
 'Q1983062': {'description': 'part of a dramatic work such as a serial television or radio program',
  'name': 'episode',
  'superclasses': {'Q15416', 'Q36649'},
  'wikilink': 'Episode'},
 'Q19887878': {'description': '',
  'name': 'Wikimedia template infobox',
  'superclasses': {'Q11266439'},
  'wikilink': ''},
 'Q200250': {'description': 'very large and significant city or urban area',
  'name': 'metropolis',
  'superclasses': {'Q1549591'},
  'wikilink': 'Metropolis'},
 'Q201658': {'description': 'refers to the method based on similarities in the narrative elements from which films are constructed',
  'name': 'film genre',
  'superclasses': {'Q1792379'},
  'wikilink': 'Film genre'},
 'Q202444': {'description': 'name that differentiates persons from a same family',
  'name': 'given name',
  'superclasses': {'Q10856962', 'Q82799'},
  'wikilink': 'Given name'},
 'Q202686': {'description': 'sovereign state within the Commonwealth of Nations that has Elizabeth II as its monarch',
  'name': 'Commonwealth realm',
  'superclasses': {'Q3624078', 'Q7269'},
  'wikilink': 'Commonwealth realm'},
 'Q2031291': {'description': 'term in the music industry',
  'name': 'release',
  'superclasses': set(),
  'wikilink': 'Release (music)'},
 'Q208511': {'description': 'city generally considered to be an important node in the global economic system',
  'name': 'global city',
  'superclasses': {'Q515'},
  'wikilink': 'Global city'},
 'Q2085381': {'description': 'company that prints and distributes pressed goods',
  'name': 'publisher',
  'superclasses': {'Q1331793'},
  'wikilink': ''},
 'Q210167': {'description': 'software developer which creates video games',
  'name': 'video game developer',
  'superclasses': {'Q4830453'},
  'wikilink': 'Video game developer'},
 'Q21032617': {'description': 'members of US federal National Sea Grant College Program',
  'name': 'sea grant institution',
  'superclasses': {'Q1849445'},
  'wikilink': ''},
 'Q21191134': {'description': '',
  'name': 'comic strip series',
  'superclasses': {'Q14406742', 'Q7725310'},
  'wikilink': ''},
 'Q213369': {'description': 'comics published online',
  'name': 'webcomic',
  'superclasses': {'Q1004'},
  'wikilink': 'Webcomic'},
 'Q215380': {'description': 'group of people who perform instrumental or vocal music',
  'name': 'band',
  'superclasses': {'Q2088357'},
  'wikilink': ''},
 'Q218616': {'description': 'computer software released under a license restricting use and redistribution',
  'name': 'proprietary software',
  'superclasses': {'Q7397'},
  'wikilink': 'Proprietary software'},
 'Q223393': {'description': 'category of literary composition',
  'name': 'literary genre',
  'superclasses': {'Q483394'},
  'wikilink': 'Literary genre'},
 'Q223832': {'description': 'autonomous polities that were nominally under British sovereignty',
  'name': 'dominion',
  'superclasses': {'Q161243'},
  'wikilink': 'Dominion'},
 'Q2264924': {'description': '',
  'name': 'port city',
  'superclasses': {'Q44782', 'Q515'},
  'wikilink': ''},
 'Q245204': {'description': 'character, group of characters, or institution that represents the opposition',
  'name': 'antagonist',
  'superclasses': {'Q636497'},
  'wikilink': 'Antagonist'},
 'Q24856': {'description': 'collection of related films in succession',
  'name': 'film series',
  'superclasses': {'Q36649', 'Q7725310'},
  'wikilink': 'Film series'},
 'Q24862': {'description': 'any film not long enough to be considered a feature film',
  'name': 'short film',
  'superclasses': {'Q11424'},
  'wikilink': 'Short film'},
 'Q2490': {'description': 'spiral galaxy with a central bar-shaped structure composed of stars',
  'name': 'barred spiral galaxy',
  'superclasses': {'Q2488'},
  'wikilink': 'Barred spiral galaxy'},
 'Q2623733': {'description': 'language in fictional stories',
  'name': 'fictional language',
  'superclasses': {'Q1078597', 'Q14897293', 'Q315'},
  'wikilink': 'Fictional language'},
 'Q2755547': {'description': '',
  'name': 'individual sport',
  'superclasses': {'Q31629'},
  'wikilink': 'Individual sport'},
 'Q2775969': {'description': 'fictional planet which appears in various media',
  'name': 'fictional planet',
  'superclasses': {'Q15831598'},
  'wikilink': 'Planets in science fiction'},
 'Q278379': {'description': '',
  'name': 'a priori language',
  'superclasses': {'Q33215'},
  'wikilink': 'A priori (languages)'},
 'Q28640': {'description': 'vocation founded upon specialized educational training',
  'name': 'profession',
  'superclasses': {'Q13516667'},
  'wikilink': 'Profession'},
 'Q2917506': {'description': 'Wikipedia disambiguation page',
  'name': 'series',
  'superclasses': set(),
  'wikilink': 'Series'},
 'Q299191': {'description': 'game related to, derived from or inspired by chess.',
  'name': 'chess variant',
  'superclasses': {'Q718'},
  'wikilink': 'List of chess variants'},
 'Q303618': {'description': '',
  'name': 'diplomatic rank',
  'superclasses': {'Q4164871', 'Q4223088'},
  'wikilink': 'Diplomatic rank'},
 'Q3046146': {'description': 'two people who are married to each other',
  'name': 'married couple',
  'superclasses': {'Q219160'},
  'wikilink': ''},
 'Q318': {'description': 'astronomical structure',
  'name': 'galaxy',
  'superclasses': {'Q6999'},
  'wikilink': 'Galaxy'},
 'Q3252662': {'description': 'last installment of a series',
  'name': 'series finale',
  'superclasses': {'Q1983062'},
  'wikilink': 'Series finale'},
 'Q3297186': {'description': 'comic book series of predetermined length',
  'name': 'limited series',
  'superclasses': {'Q14406742'},
  'wikilink': 'Limited series (comics)'},
 'Q33215': {'description': '',
  'name': 'constructed language',
  'superclasses': {'Q17537576', 'Q34770'},
  'wikilink': 'Constructed language'},
 'Q33742': {'description': 'language naturally spoken by humans, as opposed to "formal" or "built" languages',
  'name': 'natural language',
  'superclasses': {'Q34770'},
  'wikilink': 'Natural language'},
 'Q3409032': {'description': "given name used regardless of the person's sex",
  'name': 'unisex name',
  'superclasses': {'Q202444'},
  'wikilink': 'Unisex name'},
 'Q341': {'description': 'software for which certain user freedoms to use, copy, modify, redistribute it (including modified) exist',
  'name': 'free software',
  'superclasses': {'Q14075', 'Q5500964', 'Q7397'},
  'wikilink': 'Free software'},
 'Q3464665': {'description': 'set of episodes produced for a television series',
  'name': 'television season',
  'superclasses': {'Q7725310'},
  'wikilink': ''},
 'Q34770': {'description': 'particular system of communication',
  'name': 'language',
  'superclasses': {'Q17376908'},
  'wikilink': ''},
 'Q3504248': {'description': 'the inner planets of the Solar System',
  'name': 'inner planets',
  'superclasses': {'Q128207', 'Q17362350'},
  'wikilink': ''},
 'Q35127': {'description': 'set of related web pages served from a single web domain',
  'name': 'website',
  'superclasses': {'Q1076968', 'Q1186952', 'Q15610833'},
  'wikilink': 'Website'},
 'Q354004': {'description': 'communication medium',
  'name': 'audio storage device',
  'superclasses': {'Q193395', 'Q340169'},
  'wikilink': ''},
 'Q35657': {'description': 'constituent political entity sharing sovereignty with the United States of America',
  'name': 'state of the United States',
  'superclasses': {'Q107390', 'Q10864048', 'Q852446'},
  'wikilink': 'U.S. state'},
 'Q3624078': {'description': 'political organisation with a centralized independent government',
  'name': 'sovereign state',
  'superclasses': {'Q7275'},
  'wikilink': 'Sovereign state'},
 'Q3658341': {'description': 'fictional character appearing in written works',
  'name': 'literary character',
  'superclasses': {'Q95074'},
  'wikilink': ''},
 'Q375336': {'description': 'organization that produces films',
  'name': 'film studio',
  'superclasses': {'Q1331793', 'Q19364326'},
  'wikilink': 'Film studio'},
 'Q3863': {'description': 'minor planet that is not comet',
  'name': 'asteroid',
  'superclasses': {'Q1022867'},
  'wikilink': 'Asteroid'},
 'Q386724': {'description': 'distinct intellectual or artistic creation',
  'name': 'work',
  'superclasses': {'Q16686448'},
  'wikilink': ''},
 'Q3918': {'description': 'academic institution for further education',
  'name': 'university',
  'superclasses': {'Q2221906', 'Q38723', 'Q811979'},
  'wikilink': 'University'},
 'Q3957': {'description': 'settlement that is bigger than a village but smaller than a city',
  'name': 'town',
  'superclasses': {'Q1048835', 'Q486972', 'Q56061'},
  'wikilink': 'Town'},
 'Q39614': {'description': 'place of burial',
  'name': 'cemetery',
  'superclasses': {'Q1370598', 'Q14524493'},
  'wikilink': 'Cemetery'},
 'Q41298': {'description': 'publication type',
  'name': 'magazine',
  'superclasses': {'Q1092563'},
  'wikilink': 'Magazine'},
 'Q41614': {'description': 'form of state',
  'name': 'constitutional monarchy',
  'superclasses': {'Q7269'},
  'wikilink': 'Constitutional monarchy'},
 'Q4167410': {'description': "type of page in the Wikimedia system. Use with P31 'instance of' for disambiguation pages",
  'name': 'Wikimedia disambiguation page',
  'superclasses': {'Q14204246', 'Q15633587'},
  'wikilink': 'Wikipedia:Disambiguation'},
 'Q4167836': {'description': '',
  'name': 'Wikimedia category',
  'superclasses': {'Q14204246', 'Q27948'},
  'wikilink': 'Wikipedia:Categorization'},
 'Q41710': {'description': 'socially defined category of people who identify with each other',
  'name': 'ethnic group',
  'superclasses': {'Q2472587', 'Q5962346'},
  'wikilink': 'Ethnic group'},
 'Q4176708': {'description': 'album containing music from another work, such as a film or opera',
  'name': 'soundtrack album',
  'superclasses': {'Q217199', 'Q482994'},
  'wikilink': 'Soundtrack album'},
 'Q4209223': {'description': 'doctrine in European legal thinking, means "state based on justice and integrity"',
  'name': 'legal state',
  'superclasses': {'Q1192543', 'Q1307214', 'Q7275'},
  'wikilink': 'Rechtsstaat'},
 'Q4226220': {'description': '',
  'name': 'Naval officer rank',
  'superclasses': {'Q56019'},
  'wikilink': 'Naval officer ranks'},
 'Q4234303': {'description': 'Working groups on Wikimedia projects',
  'name': 'WikiProject',
  'superclasses': {'Q14204246'},
  'wikilink': 'Wikipedia:WikiProject'},
 'Q43229': {'description': 'social entity with a collective goal',
  'name': 'organization',
  'superclasses': {'Q618123', 'Q874405'},
  'wikilink': 'Organization'},
 'Q4369513': {'description': '',
  'name': 'sex of humans',
  'superclasses': {'Q154136', 'Q290'},
  'wikilink': ''},
 'Q43702': {'description': 'union of partially self-governing states or regions united by a central (federal) government',
  'name': 'federation',
  'superclasses': {'Q1307214'},
  'wikilink': 'Federation'},
 'Q44127': {'description': 'a computer program or a computer to access a central resource or service on a network',
  'name': 'server',
  'superclasses': {'Q68'},
  'wikilink': 'Server (computing)'},
 'Q44782': {'description': 'location on a coast or shore containing one or more harbors',
  'name': 'port',
  'superclasses': {'Q15222213', 'Q2221906', 'Q376799'},
  'wikilink': 'Port'},
 'Q45713': {'description': 'members of the second order of divine beings',
  'name': 'Titan',
  'superclasses': {'Q178885'},
  'wikilink': 'Titan (mythology)'},
 'Q4663903': {'description': 'pages intended to serve as "Main Pages" for specific topics or areas, use with P31 \'instance of\' for them',
  'name': 'Wikimedia portal',
  'superclasses': {'Q14204246'},
  'wikilink': 'Wikipedia:Portal'},
 'Q473708': {'description': 'class of microcomputers',
  'name': 'home computer',
  'superclasses': {'Q32738'},
  'wikilink': 'Home computer'},
 'Q48264': {'description': "person's private sense of, and subjective experience of, their own gender",
  'name': 'gender identity',
  'superclasses': {'Q2254571'},
  'wikilink': 'Gender identity'},
 'Q48277': {'description': 'range of physical, mental, and behavioral characteristics distinguishing between masculinity and femininity',
  'name': 'gender',
  'superclasses': {'Q3769299'},
  'wikilink': 'Gender'},
 'Q482994': {'description': 'collection of music',
  'name': 'album',
  'superclasses': {'Q2031291', 'Q2188189', 'Q354004', 'Q4650799'},
  'wikilink': 'Album'},
 'Q4830453': {'description': 'organization involved in the trade of goods, services, or both to consumers',
  'name': 'business',
  'superclasses': {'Q362482'},
  'wikilink': 'Business'},
 'Q483394': {'description': 'category of creative works based on stylistic criteria',
  'name': 'genre',
  'superclasses': {'Q5962346'},
  'wikilink': 'Genre'},
 'Q484170': {'description': 'France territorial subdivision of a canton',
  'name': 'commune of France',
  'superclasses': {'Q11618417', 'Q15284', 'Q15640612', 'Q192498', 'Q583865'},
  'wikilink': 'Communes of France'},
 'Q49447': {'description': "philosophical or theological approach to one's place in the world and/or society",
  'name': 'world view',
  'superclasses': {'Q131841'},
  'wikilink': 'World view'},
 'Q5': {'description': "common name of Homo sapiens (Q15978631), unique extant species of the genus Homo. (See also 'fictional human (Q15632617)' and 'human who may be fictional (Q21070568)')",
  'name': 'human',
  'superclasses': {'Q164509', 'Q215627', 'Q5891007'},
  'wikilink': 'Human'},
 'Q502895': {'description': 'name generally used for a taxon, group of taxa or organism(s)',
  'name': 'common name',
  'superclasses': {'Q82799'},
  'wikilink': 'Common name'},
 'Q5119': {'description': 'primary city of a political entity (country, state, county, etc)',
  'name': 'capital',
  'superclasses': {'Q515'},
  'wikilink': 'Capital city'},
 'Q515': {'description': 'type of municipality',
  'name': 'city',
  'superclasses': {'Q1048835', 'Q486972', 'Q56061'},
  'wikilink': 'City'},
 'Q5165090': {'description': '',
  'name': 'content rating',
  'superclasses': {'Q5962346'},
  'wikilink': 'Content rating'},
 'Q526877': {'description': 'video serial broadcast on the internet',
  'name': 'web series',
  'superclasses': {'Q24862', 'Q7725310', 'Q841645'},
  'wikilink': 'Web series'},
 'Q5398426': {'description': 'connected set of television program episodes that run under the same title, possibly spanning many seasons',
  'name': 'television series',
  'superclasses': {'Q15416', 'Q15709880', 'Q2431196'},
  'wikilink': ''},
 'Q543654': {'description': 'main administrative building of a city, town or other municipality',
  'name': 'city hall',
  'superclasses': {'Q1220959', 'Q2519340'},
  'wikilink': 'Seat of local government'},
 'Q5446565': {'description': 'business organization which only exists in fiction',
  'name': 'fictional company',
  'superclasses': {'Q14623646'},
  'wikilink': 'Fictional company'},
 'Q559026': {'description': 'group of ships of a similar design',
  'name': 'ship class',
  'superclasses': {'Q18758641', 'Q2235308'},
  'wikilink': 'Ship class'},
 'Q559618': {'description': 'self-consistent fictional setting with elements that differ from the real world',
  'name': 'fictional universe',
  'superclasses': {'Q14897293'},
  'wikilink': 'Fictional universe'},
 'Q559856': {'description': '',
  'name': 'video hosting service',
  'superclasses': {'Q1210425', 'Q186165'},
  'wikilink': 'Video hosting service'},
 'Q56019': {'description': 'element of hierarchy in armed forces',
  'name': 'military rank',
  'superclasses': {'Q4120621', 'Q4189293'},
  'wikilink': 'Military rank'},
 'Q571': {'description': 'medium for a collection of words and/or pictures to represent knowledge, often manifested in bound paper and ink, or in e-books',
  'name': 'book',
  'superclasses': {'Q18593264', 'Q2342494', 'Q340169', 'Q386724', 'Q49848'},
  'wikilink': 'Book'},
 'Q581714': {'description': 'TV genre; set of regularly presented animated television programs',
  'name': 'animated series',
  'superclasses': {'Q202866', 'Q5398426'},
  'wikilink': 'Animated series'},
 'Q590870': {'description': 'art or science of motion picture photography',
  'name': 'cinematography',
  'superclasses': {'Q11633'},
  'wikilink': 'Cinematography'},
 'Q5961279': {'description': 'planet or similar body whose existence is not proven, but is speculated on by some',
  'name': 'hypothetical planet',
  'superclasses': {'Q5961257', 'Q634'},
  'wikilink': 'Hypothetical planet'},
 'Q5962346': {'description': 'organisation of objects into classes',
  'name': 'classification',
  'superclasses': {'Q36161', 'Q6423319'},
  'wikilink': ''},
 'Q615150': {'description': 'institution of higher education in the United States designated by a state to receive the benefits of the Morrill Acts of 1862 and 1890',
  'name': 'land-grant institution',
  'superclasses': {'Q1849445'},
  'wikilink': 'Land-grant university'},
 'Q6154363': {'description': 'Wikimedia category',
  'name': 'Category:Games by genre',
  'superclasses': set(),
  'wikilink': 'Category:Games by genre'},
 'Q618779': {'description': 'something given to a person or a group of people to recognize their excellence in a certain field',
  'name': 'award',
  'superclasses': {'Q286583'},
  'wikilink': 'Award'},
 'Q619610': {'description': 'will act for social security and social justice for its citizens',
  'name': 'social state',
  'superclasses': {'Q1307214'},
  'wikilink': ''},
 'Q62049': {'description': 'administrative center, or seat of government, for a county or civil parish',
  'name': 'county seat',
  'superclasses': {'Q5119'},
  'wikilink': 'County seat'},
 'Q6256': {'description': 'distinct region in geography; a broad term that can include political divisions or regions associated with distinct political characteristics',
  'name': 'country',
  'superclasses': {'Q56061'},
  'wikilink': 'Country'},
 'Q62832': {'description': 'location used for observing terrestrial or celestial events',
  'name': 'observatory',
  'superclasses': {'Q811979'},
  'wikilink': 'Observatory'},
 'Q6465': {'description': 'France territorial subdivision of a region',
  'name': 'department of France',
  'superclasses': {'Q13220204', 'Q15631874', 'Q192498', 'Q583865'},
  'wikilink': 'Departments of France'},
 'Q6505795': {'description': 'state part of Council of Europe organisation',
  'name': 'member state of the Council of Europe',
  'superclasses': {'Q1646605'},
  'wikilink': 'Member states of the Council of Europe'},
 'Q653928': {'description': 'type of arcade game',
  'name': 'pinball',
  'superclasses': {'Q192851'},
  'wikilink': 'Pinball'},
 'Q659563': {'description': 'categorization of video games',
  'name': 'video game genre',
  'superclasses': {'Q483394', 'Q7889'},
  'wikilink': 'Video game genre'},
 'Q6619679': {'description': 'humanoid species that only exists in fiction',
  'name': 'fictional humanoid',
  'superclasses': {'Q95074'},
  'wikilink': 'Lists of fictional humanoid species'},
 'Q6623809': {'description': '',
  'name': 'fictional humanoid extraterrestrial',
  'superclasses': {'Q1307329', 'Q6619679'},
  'wikilink': 'List of humanoid alien species'},
 'Q6686945': {'description': 'collaborative software that runs a wiki',
  'name': 'wiki software',
  'superclasses': {'Q2622299', 'Q474157'},
  'wikilink': 'Wiki software'},
 'Q6688521': {'description': '',
  'name': 'permanent member of the United Nations Security Council',
  'superclasses': {'Q13341593', 'Q160016'},
  'wikilink': 'Permanent members of the United Nations Security Council'},
 'Q7270': {'description': "system of government where the state's sovereignty does not rest in an individual",
  'name': 'republic',
  'superclasses': {'Q1307214'},
  'wikilink': 'Republic'},
 'Q7275': {'description': 'organised community living under a system of government; either a sovereign state, constituent state, or federated state',
  'name': 'state',
  'superclasses': {'Q1048835', 'Q43229'},
  'wikilink': 'State (polity)'},
 'Q727596': {'description': 'a part of the milky way',
  'name': 'Galactic quadrant',
  'superclasses': set(),
  'wikilink': 'Galactic quadrant (Star Trek)'},
 'Q783794': {'description': 'association or collection of individuals, whether natural persons, juridic persons, or a mixture of both',
  'name': 'company',
  'superclasses': {'Q43229'},
  'wikilink': 'Company'},
 'Q7889': {'description': 'class of electronic game',
  'name': 'video game',
  'superclasses': {'Q166142', 'Q2249149'},
  'wikilink': 'Video game'},
 'Q8076': {'description': 'interactive entertainment computer or customized computer system to display a video game',
  'name': 'video game console',
  'superclasses': {'Q15654425', 'Q241317'},
  'wikilink': 'Video game console'},
 'Q838795': {'description': 'short serialized comics',
  'name': 'comic strip',
  'superclasses': {'Q1004'},
  'wikilink': 'Comic strip'},
 'Q8473': {'description': 'organization authorized by its greater society to use lethal force',
  'name': 'military',
  'superclasses': {'Q17149090'},
  'wikilink': 'Military'},
 'Q875538': {'description': 'university that is predominantly funded by public means',
  'name': 'public university',
  'superclasses': {'Q3918'},
  'wikilink': 'Public university'},
 'Q9135': {'description': 'collection of software that manages computer hardware resources',
  'name': 'operating system',
  'superclasses': {'Q676202'},
  'wikilink': 'Operating system'},
 'Q9174': {'description': 'supernatural belief system',
  'name': 'religion',
  'superclasses': {'Q178706', 'Q49447', 'Q5390013', 'Q7257'},
  'wikilink': 'Religion'},
 'Q920890': {'description': 'operating system that operates a mobile device',
  'name': 'mobile operating system',
  'superclasses': {'Q9135'},
  'wikilink': 'Mobile operating system'},
 'Q941818': {'description': 'lightweight, portable electronic device used for gaming',
  'name': 'handheld game console',
  'superclasses': {'Q5082128', 'Q8076'},
  'wikilink': 'Handheld game console'},
 'Q95074': {'description': 'fictional person in a narrative work of arts (for human fictional character use Q15632617)',
  'name': 'fictional character',
  'superclasses': {'Q14897293', 'Q15619164', 'Q18336849'},
  'wikilink': 'Character (arts)'},
 'Q963099': {'description': 'album consisting mostly of remixes or re-recorded versions of earlier released material',
  'name': 'remix album',
  'superclasses': {'Q482994'},
  'wikilink': 'Remix album'},
 'Q989888': {'description': 'series of fictional spacecraft',
  'name': 'Starship Enterprise',
  'superclasses': {'Q18533645'},
  'wikilink': 'Starship Enterprise'}
}

# %%
len(all_instances_dict)
# Out:
# 2602

# %%
relevant_instances_dict = {}
for ide in all_instances_dict:
    types = all_instances_dict[ide]['types']
    if not types.intersection(relevant_types_dict):
        relevant_instances_dict[ide] = all_instances_dict[ide]

# %%
len(relevant_instances_dict)
# Out:
# 325

# %%
with open('pickle/star-trek_only_relevant_properties_dict.pickle', 'wb') as f:
    pickle.dump(only_relevant_properties_dict, f)

with open('pickle/star-trek_only_relevant_types_dict.pickle', 'wb') as f:
    pickle.dump(only_relevant_types_dict, f)

# %%
d={1:1,2:2}
s={4,3}
s.intersection(d)
# Out:
# set()
