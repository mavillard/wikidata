# %% [raw]
# import json
# import pickle
#
# import networkx as nx

# %%
with open('pickle/star-trek_only_relevant_properties_dict.pickle', 'rb') as f:
    only_relevant_properties_dict = pickle.load(f)

with open('pickle/star-trek_only_relevant_types_dict.pickle', 'rb') as f:
    only_relevant_types_dict = pickle.load(f)

with open('pickle/star-trek_all_instances_and_types_dict.pickle', 'rb') as f:
    all_instances_and_types_dict = pickle.load(f)

with open('pickle/star-trek_hierarchy_graph.pickle', 'rb') as f:
    hierarchy = pickle.load(f)

# %%
def get_direct_superclasses(c):
    all_neighbors = hierarchy.neighbors(c)
    direct_superclasses = list(filter(lambda x: hierarchy[c][x]['type'] == 'is_subclass_of', all_neighbors))
    return direct_superclasses

def get_superclasses(c):
    direct_superclasses = get_direct_superclasses(c)
    if not direct_superclasses:
        superclasses = [[c]]
    else:
        superclasses = [[c] + spclsss for c2 in direct_superclasses for spclsss in get_superclasses(c2)]
    return superclasses

def is_subclass_of(c1, c2):
    return any(map(lambda x: c2 in x, get_superclasses(c1)))

def get_closest_class(c, cs):
    cs = list(cs.keys())
    lengths = []
    for c2 in cs:
        try:
            # WARNING: if there is more than one shortest path, then it returns only one of them
            length = nx.shortest_path_length(hierarchy, c, c2)
        except nx.exception.NetworkXNoPath as e:
            length = 999
        lengths.append(length)
    min_length = min(lengths)
    closest = cs[lengths.index(min_length)]
    count_min = lengths.count(min_length)
    return closest

def get_closest_relevant_class(c):
    return get_closest_class(c, only_relevant_types_dict)

def is_subclass_of_any_relevant_class(c):
    return any(map(lambda x: is_subclass_of(c, x), only_relevant_types_dict))

def get_relevant_type(ide):
    relevant_type = None
    if ide in all_instances_and_types_dict:
        types = all_instances_and_types_dict[ide]
        if len(types) == 1:
            t = types.pop(); types.add(t)
            if is_subclass_of_any_relevant_class(t):
                relevant_type = get_closest_relevant_class(t)
        else:
            relevant_candidates = set()
            for t in types:
                if is_subclass_of_any_relevant_class(t):
                    relevant_type = get_closest_relevant_class(t)
                    relevant_candidates.add(relevant_type)
            if relevant_candidates:
                # WARNING: if there is more than one relevant_candidates, then it returns only one of them
                relevant_type = relevant_candidates.pop(); relevant_candidates.add(relevant_type)
    return relevant_type

# %%
def get_value_and_type(prop_inst):
    try:
        main_info = prop_inst['mainsnak'] # for properties themselves
    except KeyError as e:
        main_info = prop_inst # for qualifiers
    prop_type = main_info['datavalue']['type']
    if prop_type == 'wikibase-entityid':
        value = 'Q' + str(main_info['datavalue']['value']['numeric-id'])
        typ = 'object'
    elif prop_type == 'string':
        value = str(main_info['datavalue']['value'])
        typ = 'string'
    elif prop_type == 'time':
        value = str(main_info['datavalue']['value']['time'][1:11])
        typ = 'date'
    elif prop_type == 'monolingualtext':
        value = str(main_info['datavalue']['value']['text'])
        typ = 'string'
    else:
        # WARNING: Unknown property type
        raise Exception('Unknown property type')
    return (value, typ)

# %%
only_relevant_instances_dict = {} # all relevant information for instances of relevant types

# %%
# %%time

total = 0
count = 0
error = 0
with open('data/wikidata-20150907-star_trek.json') as f:
    for line in f:
        try:
            total += 1
            cleaned = line.strip()[:-1]
            d = json.loads(cleaned) # keys: ['type', 'labels', 'descriptions', 'claims', 'aliases', 'sitelinks', 'id']
            ide = d['id']
            typ = get_relevant_type(ide)
            if typ:
                if 'en' in d['labels']:
                    name = d['labels']['en']['value']
                else:
                    name = ''
                if 'enwiki' in d['sitelinks']:
                    wikilink = d['sitelinks']['enwiki']['title']
                else:
                    wikilink = ''
                if 'en' in d['descriptions']:
                    description = d['descriptions']['en']['value']
                else:
                    description = ''
                info = {
                    'id': ide,
                    'type': typ,
                    'name': name,
                    'wikilink': wikilink,
                    'description': description,
                    'properties': {},
                }
                for prop in d['claims']:
                    if prop in only_relevant_properties_dict and prop != 'P31' and prop != 'P279':
                        values = []
                        for prop_inst in d['claims'][prop]:
                            p_value_and_type = get_value_and_type(prop_inst)
                            p_value = p_value_and_type[0]
                            p_type = p_value_and_type[1]
                            qualifiers = {}
                            if 'qualifiers' in prop_inst:
                                for q in prop_inst['qualifiers']:
                                    if q in only_relevant_properties_dict:
                                        q_values = []
                                        for q_inst in prop_inst['qualifiers'][q]:
                                            q_value_and_type = get_value_and_type(q_inst)
                                            q_value = q_value_and_type[0]
                                            q_type = q_value_and_type[1]
                                            q_values.append({'value': q_value, 'type': q_type})
                                        qualifiers[q] = q_values
                            values.append({'value': p_value, 'type': p_type, 'qualifiers': qualifiers})
                        info['properties'][prop] = values
                only_relevant_instances_dict[ide] = info
                count += 1
        except Exception as e:
            print(e)
            error += 1
print('Total:', total)
print('Count:', count)
print('Error:', error)
# Out:
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Total: 1630
# Count: 915
# Error: 2
# CPU times: user 6.25 s, sys: 11.7 ms, total: 6.26 s
# Wall time: 6.26 s

# %%
len(only_relevant_instances_dict)
# Out:
# 915

# %%
only_relevant_instances_dict
# Out:
# {'Q10134': {'description': 'constructed language',
#   'id': 'Q10134',
#   'name': 'Klingon language',
#   'properties': {'P1080': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q18043309'}],
#    'P373': [{'qualifiers': {}, 'type': 'string', 'value': 'Klingon language'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/049ph'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q8574920'}]},
#   'type': 'Q33215',
#   'wikilink': 'Klingon language'},
#  'Q1016685': {'description': 'Star Trek: Voyager episode',
#   'id': 'Q1016685',
#   'name': 'The Cloud',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q661255'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5422700'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708978'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3465791'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/09d915'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Cloud (Star Trek: Voyager)'},
#  'Q1027348': {'description': '',
#   'id': 'Q1027348',
#   'name': 'The Expanse',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q861686'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1185745'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572254'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q664160'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/068dtm'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Expanse (Star Trek: Enterprise)'},
#  'Q1027877': {'description': '85th episode of the television series Star Trek: Deep Space Nine',
#   'id': 'Q1027877',
#   'name': 'Crossfire',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1027888'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092502'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708521'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468897'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Crossfire (Star Trek: Deep Space Nine)'},
#  'Q1027888': {'description': 'Star Trek Episode',
#   'id': 'Q1027888',
#   'name': 'Paradise Lost',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q602612'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1027877'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708575'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468897'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Paradise Lost (Star Trek: Deep Space Nine)'},
#  'Q10361338': {'description': '',
#   'id': 'Q10361338',
#   'name': 'Rightful Heir',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7649264'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7443179'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708767'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q733620'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P921': [{'qualifiers': {}, 'type': 'object', 'value': 'Q120877'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Rightful Heir'},
#  'Q10546277': {'description': '',
#   'id': 'Q10546277',
#   'name': '',
#   'properties': {},
#   'type': 'Q15416',
#   'wikilink': ''},
#  'Q1058477': {'description': 'Star Trek: The Next Generation episode',
#   'id': 'Q1058477',
#   'name': 'The Neutral Zone',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3280032'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3441905'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q978153'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1988-05-16'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/02f90h'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Neutral Zone (Star Trek: The Next Generation)'},
#  'Q1070917': {'description': '',
#   'id': 'Q1070917',
#   'name': 'Maquis',
#   'properties': {'P646': [{'qualifiers': {},
#      'type': 'string',
#      'value': '/m/06r0t'}]},
#   'type': 'Q15416',
#   'wikilink': 'Maquis (Star Trek)'},
#  'Q1077': {'description': 'television series from the 1960s',
#   'id': 'Q1077',
#   'name': 'Star Trek: The Original Series',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q336059'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q20922'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P1811': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1257895'}],
#    'P244': [{'qualifiers': {}, 'type': 'string', 'value': 'n80040317'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0060028'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Star Trek: The Original Series'}],
#    'P449': [{'qualifiers': {}, 'type': 'object', 'value': 'Q13974'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P580': [{'qualifiers': {}, 'type': 'date', 'value': '1966-09-08'}],
#    'P582': [{'qualifiers': {}, 'type': 'date', 'value': '1969-09-02'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/06qwh'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7290476'}]},
#   'type': 'Q5398426',
#   'wikilink': 'Star Trek: The Original Series'},
#  'Q107940': {'description': '1979 American science fiction film',
#   'id': 'Q107940',
#   'name': 'Star Trek: The Motion Picture',
#   'properties': {'P1258': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'm/star_trek_the_motion_picture'}],
#    'P1265': [{'qualifiers': {}, 'type': 'string', 'value': '13022'}],
#    'P136': [{'qualifiers': {}, 'type': 'object', 'value': 'Q471839'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q319221'}],
#    'P144': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q465478'}],
#    'P1562': [{'qualifiers': {}, 'type': 'string', 'value': 'v46515'}],
#    'P1804': [{'qualifiers': {}, 'type': 'string', 'value': '1028'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0079945'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1979-01-01'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/01pg1t'}],
#    'P856': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'http://www.startrek.com/page/star-trek-the-motion-picture'}],
#    'P905': [{'qualifiers': {}, 'type': 'string', 'value': '8705'}]},
#   'type': 'Q11424',
#   'wikilink': 'Star Trek: The Motion Picture'},
#  'Q10857017': {'description': '',
#   'id': 'Q10857017',
#   'name': 'In the Flesh',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5422369'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7091852'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708912'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730030'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'In the Flesh (Star Trek: Voyager)'},
#  'Q1087392': {'description': 'fictional weapon',
#   'id': 'Q1087392',
#   'name': 'Phaser',
#   'properties': {},
#   'type': 'Q15416',
#   'wikilink': ''},
#  'Q108774': {'description': 'science fiction television series',
#   'id': 'Q108774',
#   'name': 'Star Trek: Deep Space Nine',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q336059'}],
#    'P155': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P1811': [{'qualifiers': {}, 'type': 'object', 'value': 'Q914249'}],
#    'P244': [{'qualifiers': {}, 'type': 'string', 'value': 'n94088268'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0106145'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Star Trek: Deep Space Nine'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/06qw_'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q8810438'}]},
#   'type': 'Q5398426',
#   'wikilink': 'Star Trek: Deep Space Nine'},
#  'Q1092': {'description': 'science fiction franchise',
#   'id': 'Q1092',
#   'name': 'Star Trek',
#   'properties': {'P1235': [{'qualifiers': {},
#      'type': 'string',
#      'value': '314'}],
#    'P136': [{'qualifiers': {}, 'type': 'object', 'value': 'Q24925'}],
#    'P1434': [{'qualifiers': {}, 'type': 'object', 'value': 'Q18043309'}],
#    'P2002': [{'qualifiers': {}, 'type': 'string', 'value': 'StarTrek'}],
#    'P2003': [{'qualifiers': {}, 'type': 'string', 'value': 'startrek'}],
#    'P2013': [{'qualifiers': {}, 'type': 'string', 'value': 'StarTrek'}],
#    'P373': [{'qualifiers': {}, 'type': 'string', 'value': 'Star Trek'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P553': [{'qualifiers': {}, 'type': 'object', 'value': 'Q866'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/06mv6'}],
#    'P856': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'http://startrek.com'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7155418'}]},
#   'type': 'Q196600',
#   'wikilink': 'Star Trek'},
#  'Q1092502': {'description': '',
#   'id': 'Q1092502',
#   'name': 'Return to Grace',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1027877'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7562328'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708590'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468897'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Return to Grace'},
#  'Q1102217': {'description': 'film series',
#   'id': 'Q1102217',
#   'name': 'Star Trek',
#   'properties': {'P361': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1092'}],
#    'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Star Trek (film franchise)'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7208476'}]},
#   'type': 'Q24856',
#   'wikilink': 'Star Trek (film series)'},
#  'Q1102231': {'description': 'Star Trek: The Next Generation episode',
#   'id': 'Q1102231',
#   'name': 'Hide and Q',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q785059'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3231778'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708728'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q978153'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/056zqn'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Hide and Q'},
#  'Q1115005': {'description': '',
#   'id': 'Q1115005',
#   'name': 'Star Trek: Elite Force II',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q185029'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P348': [{'qualifiers': {}, 'type': 'string', 'value': '1.1'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7982'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '2003-06-20'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/08jgkg'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek: Elite Force II'},
#  'Q1136071': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q1136071',
#   'name': 'The Doomsday Machine',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3488828'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3487187'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468578'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/025g35'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Doomsday Machine (Star Trek: The Original Series)'},
#  'Q1136084': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q1136084',
#   'name': 'The Trouble With Tribbles',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3487137'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3488463'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708480'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468578'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/023wyz'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Trouble with Tribbles'},
#  'Q1141170': {'description': 'an episode of star Trek: The Next Generation',
#   'id': 'Q1141170',
#   'name': 'Chain of Command',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7758878'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6270441'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q733620'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/0b3gjl'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Chain of Command (Star Trek: The Next Generation)'},
#  'Q1143426': {'description': 'multiplayer online game',
#   'id': 'Q1143426',
#   'name': 'Star Trek Online',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q24925'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q14116'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5294'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '2010-02-02'}],
#    'P852': [{'qualifiers': {}, 'type': 'object', 'value': 'Q14864330'}],
#    'P908': [{'qualifiers': {}, 'type': 'object', 'value': 'Q14915515'}],
#    'P914': [{'qualifiers': {}, 'type': 'object', 'value': 'Q14920392'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek Online'},
#  'Q1165846': {'description': '2000 video game',
#   'id': 'Q1165846',
#   'name': 'Star Trek: Klingon Academy',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1892535'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7982'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '2000-06-21'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/0dq382'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek: Klingon Academy'},
#  'Q11729803': {'description': 'Star Trek: The Animated Series episode',
#   'id': 'Q11729803',
#   'name': 'The Terratin Incident',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q6931590'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7769334'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q20922'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Terratin Incident'},
#  'Q11756023': {'description': '',
#   'id': 'Q11756023',
#   'name': 'Wikipedia:WikiProject Star Trek',
#   'properties': {'P910': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7364902'}]},
#   'type': 'Q4234303',
#   'wikilink': 'Wikipedia:WikiProject Star Trek'},
#  'Q11774134': {'description': 'Star Trek: The Animated Series episode',
#   'id': 'Q11774134',
#   'name': 'More Tribbles, More Troubles',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7748494'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7767549'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q20922'}]},
#   'type': 'Q1983062',
#   'wikilink': 'More Tribbles, More Troubles'},
#  'Q1185745': {'description': '',
#   'id': 'Q1185745',
#   'name': 'The Xindi',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1027348'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q2153354'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572259'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q610142'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Xindi'},
#  'Q11863377': {'description': '',
#   'id': 'Q11863377',
#   'name': 'The House of Quark',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7762826'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5384474'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468785'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The House of Quark'},
#  'Q1187077': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q1187077',
#   'name': 'The Corbomite Maneuver',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3107459'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q25366'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q619989'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/042nvh'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Corbomite Maneuver'},
#  'Q12031611': {'description': '',
#   'id': 'Q12031611',
#   'name': 'The Circle',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q12041709'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7764112'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468580'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Circle (Star Trek: Deep Space Nine)'},
#  'Q12036362': {'description': 'episode of Star Trek: Deep Space Nine',
#   'id': 'Q12036362',
#   'name': 'Melora',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5038249'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7379022'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468580'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Melora'},
#  'Q12036402': {'description': 'Star Trek episode',
#   'id': 'Q12036402',
#   'name': 'Meridian',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5124470'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5251542'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468785'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Meridian (Star Trek: Deep Space Nine)'},
#  'Q12041492': {'description': '',
#   'id': 'Q12041492',
#   'name': 'Necessary Evil',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7379022'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7443536'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468580'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Necessary Evil (Star Trek: Deep Space Nine)'},
#  'Q12041709': {'description': '',
#   'id': 'Q12041709',
#   'name': 'The Homecoming',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q6012254'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q12031611'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468580'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Homecoming (Star Trek: Deep Space Nine)'},
#  'Q12059643': {'description': '',
#   'id': 'Q12059643',
#   'name': 'Tribunal',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7726666'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7743099'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468580'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Tribunal (Star Trek: Deep Space Nine)'},
#  'Q125917': {'description': 'episode on the TV series Star Trek: Voyager',
#   'id': 'Q125917',
#   'name': 'Q2',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q16744675'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q4825905'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708952'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730033'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Q2 (Star Trek: Voyager)'},
#  'Q1262613': {'description': 'date in Star Trek',
#   'id': 'Q1262613',
#   'name': 'Stardate',
#   'properties': {'P646': [{'qualifiers': {},
#      'type': 'string',
#      'value': '/m/01t55_'}]},
#   'type': 'Q15416',
#   'wikilink': 'Stardate'},
#  'Q1287667': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q1287667',
#   'name': 'The Man Trap',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q20909'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q2659593'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708469'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1966-01-01'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/0406ft'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Man Trap'},
#  'Q13115900': {'description': '',
#   'id': 'Q13115900',
#   'name': 'Initiations',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7711875'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7249457'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468582'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Initiations (Star Trek: Voyager)'},
#  'Q13115914': {'description': '',
#   'id': 'Q13115914',
#   'name': 'Investigations',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q6545463'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q269313'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468582'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Investigations (Star Trek: Voyager)'},
#  'Q1315800': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q1315800',
#   'name': 'The Devil in the Dark',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5221200'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3488859'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/03nwrv'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Devil in the Dark'},
#  'Q1329701': {'description': 'episode of Star Trek: Voyager',
#   'id': 'Q1329701',
#   'name': 'Equinox',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7969397'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7647180'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708887'},
#     {'qualifiers': {}, 'type': 'string', 'value': 'tt0708888'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730030'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q3730032'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Equinox (Star Trek: Voyager)'},
#  'Q13403516': {'description': '',
#   'id': 'Q13403516',
#   'name': 'Virtuoso',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q4926755'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6815335'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730032'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Virtuoso (Star Trek: Voyager)'},
#  'Q13479268': {'description': 'episode of Star Trek: Voyager',
#   'id': 'Q13479268',
#   'name': 'Ashes to Ashes',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7577884'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5097656'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730032'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730032'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Ashes to Ashes (Star Trek: Voyager)'},
#  'Q13639300': {'description': '',
#   'id': 'Q13639300',
#   'name': 'Jetrel',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5428493'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6510101'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3465791'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Jetrel'},
#  'Q1392472': {'description': 'Star Trek: The Next Generation episode',
#   'id': 'Q1392472',
#   'name': 'Skin of Evil',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3444480'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3444400'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q978153'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/05kvq2'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Skin of Evil'},
#  'Q14045941': {'description': 'Star Trek: The Next Generation episode',
#   'id': 'Q14045941',
#   'name': 'Brothers',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5231126'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7633644'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468901'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Brothers (Star Trek: The Next Generation)'},
#  'Q1412961': {'description': '',
#   'id': 'Q1412961',
#   'name': 'Trekkie',
#   'properties': {'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Trekkie'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/07nh4'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q8810502'}]},
#   'type': 'Q15416',
#   'wikilink': 'Star Trek fandom'},
#  'Q14414302': {'description': 'game of chance in Star Trek',
#   'id': 'Q14414302',
#   'name': 'Dabo',
#   'properties': {},
#   'type': 'Q15416',
#   'wikilink': ''},
#  'Q14476529': {'description': '',
#   'id': 'Q14476529',
#   'name': 'The Q and the Grey',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7969525'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6725235'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468788'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'The Q and the Grey'},
#  'Q1461062': {'description': '',
#   'id': 'Q1461062',
#   'name': '',
#   'properties': {},
#   'type': 'Q15416',
#   'wikilink': ''},
#  'Q14643756': {'description': 'TV episode',
#   'id': 'Q14643756',
#   'name': 'Think tank',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7733795'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16744043'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730030'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Think Tank (Star Trek: Voyager)'},
#  'Q1474668': {'description': 'computer strategy game',
#   'id': 'Q1474668',
#   'name': 'Star Trek: The Next Generation: Birth of the Federation',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q2176159'}],
#    'P144': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P348': [{'qualifiers': {}, 'type': 'string', 'value': '1.0.2'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7982'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1999-05-25'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/03qq3n'}],
#    'P914': [{'qualifiers': {}, 'type': 'object', 'value': 'Q14920387'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek: Birth of the Federation'},
#  'Q15034077': {'description': '',
#   'id': 'Q15034077',
#   'name': 'The Kobayashi Maru (1989 novel)',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q24925'}],
#    'P155': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7728306'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7379028'}],
#    'P243': [{'qualifiers': {}, 'type': 'string', 'value': '20763326'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P957': [{'qualifiers': {}, 'type': 'string', 'value': '0-671-65817-4'}]},
#   'type': 'Q571',
#   'wikilink': 'The Kobayashi Maru (Star Trek novel)'},
#  'Q15040824': {'description': '',
#   'id': 'Q15040824',
#   'name': 'Star Trek: Planet of the Titans',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q471839'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q319221'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}]},
#   'type': 'Q11424',
#   'wikilink': 'Star Trek: Planet of the Titans'},
#  'Q15131926': {'description': 'fan based Star Trek episode released in 2013',
#   'id': 'Q15131926',
#   'name': 'Pilgrim of Eternity',
#   'properties': {'P1651': [{'qualifiers': {},
#      'type': 'string',
#      'value': '3G-ziTBAkbQ'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q18148973'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt2751228'}]},
#   'type': 'Q24862',
#   'wikilink': 'Pilgrim of Eternity'},
#  'Q156329': {'description': 'television series',
#   'id': 'Q156329',
#   'name': 'Star Trek: Voyager',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q336059'}],
#    'P155': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1092'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0112178'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Star Trek: Voyager'}],
#    'P449': [{'qualifiers': {}, 'type': 'object', 'value': 'Q206272'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P580': [{'qualifiers': {}, 'type': 'date', 'value': '1995-01-16'}],
#    'P582': [{'qualifiers': {}, 'type': 'date', 'value': '2001-05-23'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q8810475'}]},
#   'type': 'Q5398426',
#   'wikilink': 'Star Trek: Voyager'},
#  'Q15850703': {'description': '',
#   'id': 'Q15850703',
#   'name': '',
#   'properties': {'P345': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'tt1489257'}]},
#   'type': 'Q11424',
#   'wikilink': ''},
#  'Q15882750': {'description': '',
#   'id': 'Q15882750',
#   'name': '',
#   'properties': {},
#   'type': 'Q1983062',
#   'wikilink': ''},
#  'Q16248700': {'description': '',
#   'id': 'Q16248700',
#   'name': 'Star Trek Generations: Beyond the Nexus',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q270948'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q186437'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q633454'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1994-12-31'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek Generations: Beyond the Nexus'},
#  'Q16290': {'description': 'American science fiction television series',
#   'id': 'Q16290',
#   'name': 'Star Trek: The Next Generation',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q336059'}],
#    'P1407': [{'qualifiers': {},
#      'type': 'string',
#      'value': '7f3ff771-b7d9-4215-b573-2e7bb49c484a'}],
#    'P155': [{'qualifiers': {}, 'type': 'object', 'value': 'Q20922'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P1811': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1137046'}],
#    'P244': [{'qualifiers': {}, 'type': 'string', 'value': 'n85039387'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0092455'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1102217'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P373': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'Star Trek: The Next Generation'}],
#    'P449': [{'qualifiers': {}, 'type': 'object', 'value': 'Q260531'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/06qv_'}],
#    'P910': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6529265'}],
#    'P915': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1093941'}]},
#   'type': 'Q5398426',
#   'wikilink': 'Star Trek: The Next Generation'},
#  'Q16385914': {'description': 'Star Trek novel',
#   'id': 'Q16385914',
#   'name': 'Harbinger',
#   'properties': {},
#   'type': 'Q571',
#   'wikilink': 'Harbinger (Star Trek novel)'},
#  'Q1653324': {'description': '',
#   'id': 'Q1653324',
#   'name': 'Cosmicolor',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q6712056'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5357271'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/03g3t2z'}]},
#   'type': 'Q482994',
#   'wikilink': 'Cosmicolor'},
#  'Q16743891': {'description': '',
#   'id': 'Q16743891',
#   'name': 'I, Borg',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q6002452'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7753998'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468983'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'I, Borg'},
#  'Q16744016': {'description': '',
#   'id': 'Q16744016',
#   'name': 'Countdown (Star Trek: Enterprise)',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7727741'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q8069524'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q610142'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Countdown (Star Trek: Enterprise)'},
#  'Q16744043': {'description': '',
#   'id': 'Q16744043',
#   'name': 'Juggernaut',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q14643756'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7559720'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730030'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Juggernaut (Star Trek: Voyager)'},
#  'Q16744047': {'description': '',
#   'id': 'Q16744047',
#   'name': 'Half a Life',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7731084'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7740379'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468901'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Half a Life (Star Trek: The Next Generation)'},
#  'Q16744066': {'description': '',
#   'id': 'Q16744066',
#   'name': 'Infinite Regress',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7805539'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7062763'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730030'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Infinite Regress (Star Trek: Voyager)'},
#  'Q16744084': {'description': '',
#   'id': 'Q16744084',
#   'name': 'Inter Arma Enim Silent Leges',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q4840668'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7165351'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730026'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Inter Arma Enim Silent Leges (Star Trek: Deep Space Nine)'},
#  'Q16744119': {'description': '',
#   'id': 'Q16744119',
#   'name': 'Silicon Avatar',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5380005'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5281321'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468983'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Silicon Avatar'},
#  'Q16744120': {'description': '',
#   'id': 'Q16744120',
#   'name': 'New Ground',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q4658168'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16744121'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468983'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'New Ground (Star Trek: The Next Generation)'},
#  'Q16744121': {'description': '',
#   'id': 'Q16744121',
#   'name': 'Hero Worship',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q16744120'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7933105'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468983'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Hero Worship (Star Trek: The Next Generation)'},
#  'Q16744156': {'description': '',
#   'id': 'Q16744156',
#   'name': 'Image in the Sand',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7691829'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7460803'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730026'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Image in the Sand'},
#  'Q16744174': {'description': '',
#   'id': 'Q16744174',
#   'name': 'His Way',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q471896'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7759792'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q461787'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'His Way'},
#  'Q16744188': {'description': '',
#   'id': 'Q16744188',
#   'name': 'Favor the Bold',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q4880854'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7397363'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q461787'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Favor the Bold'},
#  'Q16744191': {'description': '',
#   'id': 'Q16744191',
#   'name': 'Natural Law',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5504409'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5890492'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730033'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Natural Law (Star Trek: Voyager)'},
#  'Q16744675': {'description': '164th episode of Star Trek: Voyager (season 7, episode 18)',
#   'id': 'Q16744675',
#   'name': 'Human Error',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q8034838'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q125917'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730033'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
# ...
#   'name': 'Worst Case Scenario',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5282602'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3511648'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0709013'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468788'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Worst Case Scenario (Star Trek: Voyager)'},
#  'Q8038644': {'description': '',
#   'id': 'Q8038644',
#   'name': 'Wrongs Darker Than Death or Night',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5071858'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q6036887'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708666'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q461787'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Wrongs Darker Than Death or Night'},
#  'Q8050895': {'description': '',
#   'id': 'Q8050895',
#   'name': 'Year of Hell',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q24925'}],
#    'P155': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7433765'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7291955'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730029'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Year of Hell'},
#  'Q8057703': {'description': '',
#   'id': 'Q8057703',
#   'name': 'You are Cordially Invited...',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7397363'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7316518'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708667'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q461787'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'You Are Cordially Invited...'},
#  'Q8069524': {'description': '2004 episode of Star Trek: Enterprise',
#   'id': 'Q8069524',
#   'name': 'Zero Hour',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q16744016'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7620128'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572267'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q610142'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Zero Hour (Star Trek: Enterprise)'},
#  'Q8078964': {'description': '',
#   'id': 'Q8078964',
#   'name': 'Ömer the Tourist in Star Trek',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q471839'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0182503'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q256'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q43'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1973-01-01'}]},
#   'type': 'Q11424',
#   'wikilink': 'Ömer the Tourist in Star Trek'},
#  'Q81313': {'description': '',
#   'id': 'Q81313',
#   'name': 'Little Green Men',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7602415'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7767762'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q108774'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708565'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468897'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Little Green Men (Star Trek: Deep Space Nine)'},
#  'Q827164': {'description': '',
#   'id': 'Q827164',
#   'name': 'Star Trek: Of Gods and Men',
#   'properties': {'P345': [{'qualifiers': {},
#      'type': 'string',
#      'value': 'tt0835378'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/0kv1tt'}]},
#   'type': 'Q11424',
#   'wikilink': 'Star Trek: Of Gods and Men'},
#  'Q831478': {'description': 'A space combat simulation video game based on Star Trek',
#   'id': 'Q831478',
#   'name': 'Star Trek: Bridge Commander',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1892535'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7982'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '2002-02-27'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/01ddy_'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek: Bridge Commander'},
#  'Q8563741': {'description': '',
#   'id': 'Q8563741',
#   'name': 'Flesh and Blood',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7033819'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7490690'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0394912'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730033'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Flesh and Blood (Star Trek: Voyager)'},
#  'Q861673': {'description': '',
#   'id': 'Q861673',
#   'name': 'First Flight',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q764748'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q861686'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572210'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q664160'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'First Flight (Star Trek: Enterprise)'},
#  'Q861686': {'description': '',
#   'id': 'Q861686',
#   'name': 'Bounty',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q861673'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1027348'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572181'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q664160'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Bounty (Star Trek: Enterprise)'},
#  'Q865358': {'description': '',
#   'id': 'Q865358',
#   'name': 'Cause and Effect',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7755633'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7734119'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708685'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468983'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/0266dj'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Cause and Effect (Star Trek: The Next Generation)'},
#  'Q866375': {'description': '',
#   'id': 'Q866375',
#   'name': 'In a Mirror, Darkly',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q4949851'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5256284'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q380519'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0572219'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3468898'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/05_bgw'}]},
#   'type': 'Q1983062',
#   'wikilink': 'In a Mirror, Darkly'},
#  'Q891149': {'description': 'principle in Star Trek',
#   'id': 'Q891149',
#   'name': 'Prime Directive',
#   'properties': {'P646': [{'qualifiers': {},
#      'type': 'string',
#      'value': '/m/0ckkt'}]},
#   'type': 'Q15416',
#   'wikilink': 'Prime Directive'},
#  'Q897951': {'description': '',
#   'id': 'Q897951',
#   'name': 'Message in a Bottle',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7961167'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q5944738'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708931'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3730029'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Message in a Bottle (Star Trek: Voyager)'},
#  'Q901789': {'description': 'Star Trek: The Next Generation episode',
#   'id': 'Q901789',
#   'name': '11001001',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q3231803'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3435679'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q978153'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/02_xzc'}]},
#   'type': 'Q1983062',
#   'wikilink': '11001001'},
#  'Q926323': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q926323',
#   'name': 'Miri',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q981113'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3107459'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/04269p'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Miri (Star Trek: The Original Series)'},
#  'Q932633': {'description': 'race in Star Trek',
#   'id': 'Q932633',
#   'name': 'Changeling',
#   'properties': {'P508': [{'qualifiers': {},
#      'type': 'string',
#      'value': '30420'}]},
#   'type': 'Q15416',
#   'wikilink': ''},
#  'Q936657': {'description': '',
#   'id': 'Q936657',
#   'name': 'Star Trek: Starfleet Command',
#   'properties': {'P136': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q1892535'},
#     {'qualifiers': {}, 'type': 'object', 'value': 'Q2313710'}],
#    'P400': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1406'}],
#    'P437': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7982'}],
#    'P577': [{'qualifiers': {}, 'type': 'date', 'value': '1999-07-31'}]},
#   'type': 'Q7889',
#   'wikilink': 'Star Trek: Starfleet Command'},
#  'Q95156': {'description': 'comic',
#   'id': 'Q95156',
#   'name': 'Star Trek: Countdown',
#   'properties': {},
#   'type': 'Q3297186',
#   'wikilink': 'Star Trek: Countdown'},
#  'Q95157': {'description': 'comic',
#   'id': 'Q95157',
#   'name': 'Star Trek: Nero',
#   'properties': {},
#   'type': 'Q3297186',
#   'wikilink': 'Star Trek: Nero'},
#  'Q971746': {'description': '',
#   'id': 'Q971746',
#   'name': 'Homeward',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q7756499'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q7630674'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708731'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3469077'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Homeward (Star Trek: The Next Generation)'},
#  'Q974108': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q974108',
#   'name': 'Court Martial',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q5252917'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3487430'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/042mst'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Court Martial (Star Trek: The Original Series)'},
#  'Q978153': {'description': 'season 1 of ST:TNG',
#   'id': 'Q978153',
#   'name': 'Star Trek: The Next Generation',
#   'properties': {'P156': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q604559'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q16290'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/02hqqnv'}]},
#   'type': 'Q3464665',
#   'wikilink': 'Star Trek: The Next Generation (season 1)'},
#  'Q981113': {'description': 'Star Trek: The Original Series episode',
#   'id': 'Q981113',
#   'name': 'What Are Little Girls Made Of?',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q2664096'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q926323'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1077'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q747598'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/041wjb'}]},
#   'type': 'Q1983062',
#   'wikilink': 'What Are Little Girls Made Of?'},
#  'Q987352': {'description': '',
#   'id': 'Q987352',
#   'name': 'Parallax',
#   'properties': {'P155': [{'qualifiers': {},
#      'type': 'object',
#      'value': 'Q2121683'}],
#    'P156': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1976840'}],
#    'P179': [{'qualifiers': {}, 'type': 'object', 'value': 'Q156329'}],
#    'P345': [{'qualifiers': {}, 'type': 'string', 'value': 'tt0708943'}],
#    'P361': [{'qualifiers': {}, 'type': 'object', 'value': 'Q3465791'}],
#    'P364': [{'qualifiers': {}, 'type': 'object', 'value': 'Q1860'}],
#    'P495': [{'qualifiers': {}, 'type': 'object', 'value': 'Q30'}],
#    'P646': [{'qualifiers': {}, 'type': 'string', 'value': '/m/08ft9c'}]},
#   'type': 'Q1983062',
#   'wikilink': 'Parallax (Star Trek: Voyager)'}}

# %%
# Double check
for ide in only_relevant_instances_dict:
    assert(only_relevant_instances_dict[ide]['type'] in only_relevant_types_dict)
    for prop in only_relevant_instances_dict[ide]['properties']:
        assert(prop in only_relevant_properties_dict)

# %%
with open('pickle/star-trek_only_relevant_instances_dict.pickle', 'wb') as f:
    pickle.dump(only_relevant_instances_dict, f)
